# %%
import pandas as pd

# %%
from category_encoders import BinaryEncoder

# %%
data = {
    'Device' : ['Laptop', 'TV', 'Mobile', 'Tablet'],
    'Portable' : ['Yes', 'No', 'Yes', 'Yes']
}

# %%
df = pd.DataFrame(data)

# %%
encoder = BinaryEncoder(cols=['Portable'])

# %%
en_df=encoder.fit_transform(df);

# %%
en_df
# Out:
#    Device  Portable_0  Portable_1
# 0  Laptop           0           1
# 1      TV           1           0
# 2  Mobile           0           1
# 3  Tablet           0           1
