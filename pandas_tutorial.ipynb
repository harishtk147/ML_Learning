# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = [10,20,30,40,50]
s = pd.Series(data)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#we can change the index of the series to custom index

# %%
data = [10,20,30,40,50]
custom_index = ['a','b','c','d','e']
s = pd.Series(data,index=custom_index)
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s['e']
# Out:
# np.int64(50)

# %%
res = s+5
res
# Out:
# a    15
# b    25
# c    35
# d    45
# e    55
# dtype: int64

# %%
a={
    'Name' : ['A','B','C','D'],
    'Age' : [20,21,22,23],
    'City' : ['W','X','Y','Z']
}

# %%
df = pd.DataFrame(a)
df
# Out:
#   Name  Age City
# 0    A   20    W
# 1    B   21    X
# 2    C   22    Y
# 3    D   23    Z

# %%
df['Name']
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: Name, dtype: str

# %%
df.loc[3]
# Out:
# Name     D
# Age     23
# City     Z
# Name: 3, dtype: object

# %%
df = pd.read_csv('demo_dataset.csv')
df
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.head()
# Out:
#       name   age         city  salary  weight
# 0    Alice  25.0     New York   55000      58
# 1      Bob  30.0  Los Angeles   62000      72
# 2  Charlie  28.0      Chicago   60000      68
# 3    David  35.0      Houston   72000      80
# 4     Emma  27.0      Phoenix   58000      55

# %%
#To print the number of rows we can give manually

# %%
pd.options.display.max_rows = 5

# %%
df
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     str
#  1   age     9 non-null      float64
#  2   city    10 non-null     str
#  3   salary  10 non-null     int64
#  4   weight  10 non-null     int64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 528.0 bytes

# %%
df.describe()
# Out:
#              age   salary  weight
# count   9.000000     10.0    10.0
# mean   29.444444  64900.0    68.2
# ...          ...      ...     ...
# 75%    32.000000  69250.0    77.0
# max    35.000000  85000.0    85.0
#
# [8 rows x 3 columns]

# %%
df.shape
# Out:
# (10, 5)

# %%
# To identify the NAN values in the dataset we can use the following command

# %%
df.isna().sum()
# Out:
# name      0
# age       1
# city      0
# salary    0
# weight    0
# dtype: int64

# %%
# to chnage the NAN value we can use the following command

# %%
df["age"].fillna(20, inplace=True)
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20060\2757973175.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["age"].fillna(20, inplace=True)
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ...

# %%
df.isna().sum()
# Out:
# name      0
# age       0
# city      0
# salary    0
# weight    0
# dtype: int64

# %%
df.fillna({"age": 20},inplace=True)
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.fillna(20, inplace=True)
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     str
#  1   age     10 non-null     float64
#  2   city    10 non-null     str
#  3   salary  10 non-null     int64
#  4   weight  10 non-null     int64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 528.0 bytes

# %%
x = df["age"].mean()

# %%
df.fillna({"age":x}, inplace=True)
df
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.loc[5]
# Out:
# name             Frank
# age               25.0
# city      Philadelphia
# salary           85000
# weight              85
# Name: 5, dtype: object

# %%
q = df["age"].mode()[0]

# %%
df.fillna({"age":q}, inplace=True)
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         name   age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df.rename(columns={"age":"Age"}, inplace=True)
df
# Out:
#         name   Age         city  salary  weight
# 0      Alice  25.0     New York   55000      58
# 1        Bob  30.0  Los Angeles   62000      72
# ..       ...   ...          ...     ...     ...
# 8   Isabella  26.0       Dallas   59000      52
# 9       Jack  33.0     San Jose   70000      78
#
# [10 rows x 5 columns]

# %%
df['gender']=['M','F','M','M','F','M','M','F','M','M']
df
# Out:
#         name   Age         city  salary  weight gender
# 0      Alice  25.0     New York   55000      58      M
# 1        Bob  30.0  Los Angeles   62000      72      F
# ..       ...   ...          ...     ...     ...    ...
# 8   Isabella  26.0       Dallas   59000      52      M
# 9       Jack  33.0     San Jose   70000      78      M
#
# [10 rows x 6 columns]

# %%
g = df.groupby("gender")["Age"].mean()
g
# Out:
# gender
# F    28.666667
# M    29.142857
# Name: Age, dtype: float64

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13113         """  # noqa: E501
#   13114         data = self._get_numeric_data() if numeric_only else self
#   13115         cols = data.columns
#   13116         idx = cols.copy()
# > 13117         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13118
#   13119         if method == "pearson":
#   13120             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
# ...
